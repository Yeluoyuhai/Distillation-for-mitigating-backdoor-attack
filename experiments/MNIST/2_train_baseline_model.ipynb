# %%
import os
import numpy as np
import matplotlib.pyplot as plt

import torch
import torchvision
from torchvision import transforms
import ignite
from ignite.engine import create_supervised_evaluator

import backdoor_attack as bd
import backdoor_attack.plot_util
import net

# %%
# result output folder
out = os.path.join('results', 'baseline_model')
os.makedirs(os.path.join(out), exist_ok=True)

# device setup
if torch.cuda.is_available():
    device = torch.device(type='cuda', index=1)
else:
    device = torch.device(type='cpu')

# %% [markdown]
# ## データセットの準備

# %%
transform = transforms.Compose([
    transforms.ToTensor()
])

# %%
ds_root = os.path.join('.', 'results', 'datasets')
tr = np.load(os.path.join(ds_root, 'clean_training_dataset.npz'))
train_ds = bd.Dataset_from_array(x=tr['x'], t=tr['t'], transform=transform)
te = np.load(os.path.join(ds_root, 'clean_test_dataset.npz'))
test_ds = bd.Dataset_from_array(x=te['x'], t=te['t'], transform=transform)
te_p = np.load(os.path.join(ds_root, 'poison_test_dataset.npz'))
test_p_ds = bd.Dataset_from_array(x=te_p['x'], t=te_p['t_correct'], transform=transform)

train_dl = torch.utils.data.DataLoader(train_ds, batch_size=128, shuffle=True)
test_dl = torch.utils.data.DataLoader(test_ds, batch_size=128, shuffle=False)
test_p_dl = torch.utils.data.DataLoader(test_p_ds, batch_size=128, shuffle=False)

# %% [markdown]
# ## モデルの準備

# %%
model = net.CNV()
dummy_input = torch.Tensor(np.zeros((1, 1, 28, 28)).astype(np.float32))
_ = model(dummy_input)

# %% [markdown]
# ## 学習

# %%
trainer = bd.Trainer(train_dl, test_dl, model, device)
optimizer = torch.optim.Adam
epoch = 50

trainer.run(optimizer, epoch, out)
# Out:
# 1/50 Epoch, Train/Test Loss: 0.0472/0.0544,         Train/Test Accuracy: 0.9861/0.9830,         Elapsed/Remaining time: 0.54/26.42 [min]
# 2/50 Epoch, Train/Test Loss: 0.0284/0.0443,         Train/Test Accuracy: 0.9911/0.9859,         Elapsed/Remaining time: 1.10/26.45 [min]
# 3/50 Epoch, Train/Test Loss: 0.0188/0.0408,         Train/Test Accuracy: 0.9942/0.9856,         Elapsed/Remaining time: 1.66/26.04 [min]
# 4/50 Epoch, Train/Test Loss: 0.0128/0.0467,         Train/Test Accuracy: 0.9961/0.9865,         Elapsed/Remaining time: 2.22/25.50 [min]
# 5/50 Epoch, Train/Test Loss: 0.0118/0.0502,         Train/Test Accuracy: 0.9960/0.9863,         Elapsed/Remaining time: 2.77/24.93 [min]
# 6/50 Epoch, Train/Test Loss: 0.0031/0.0377,         Train/Test Accuracy: 0.9991/0.9895,         Elapsed/Remaining time: 3.31/24.26 [min]
# 7/50 Epoch, Train/Test Loss: 0.0032/0.0449,         Train/Test Accuracy: 0.9992/0.9882,         Elapsed/Remaining time: 3.87/23.75 [min]
# 8/50 Epoch, Train/Test Loss: 0.0061/0.0539,         Train/Test Accuracy: 0.9982/0.9871,         Elapsed/Remaining time: 4.44/23.33 [min]
# 9/50 Epoch, Train/Test Loss: 0.0093/0.0599,         Train/Test Accuracy: 0.9972/0.9860,         Elapsed/Remaining time: 5.02/22.89 [min]
# 10/50 Epoch, Train/Test Loss: 0.0063/0.0545,         Train/Test Accuracy: 0.9979/0.9853,         Elapsed/Remaining time: 5.59/22.34 [min]
# 11/50 Epoch, Train/Test Loss: 0.0041/0.0580,         Train/Test Accuracy: 0.9987/0.9871,         Elapsed/Remaining time: 6.16/21.82 [min]
# 12/50 Epoch, Train/Test Loss: 0.0012/0.0499,         Train/Test Accuracy: 0.9996/0.9890,         Elapsed/Remaining time: 6.72/21.28 [min]
# 13/50 Epoch, Train/Test Loss: 0.0016/0.0559,         Train/Test Accuracy: 0.9995/0.9881,         Elapsed/Remaining time: 7.27/20.68 [min]
# 14/50 Epoch, Train/Test Loss: 0.0054/0.0643,         Train/Test Accuracy: 0.9982/0.9862,         Elapsed/Remaining time: 7.80/20.05 [min]
# 15/50 Epoch, Train/Test Loss: 0.0017/0.0590,         Train/Test Accuracy: 0.9994/0.9879,         Elapsed/Remaining time: 8.35/19.47 [min]
# 16/50 Epoch, Train/Test Loss: 0.0025/0.0595,         Train/Test Accuracy: 0.9989/0.9872,         Elapsed/Remaining time: 8.89/18.89 [min]
# 17/50 Epoch, Train/Test Loss: 0.0028/0.0697,         Train/Test Accuracy: 0.9991/0.9857,         Elapsed/Remaining time: 9.42/18.28 [min]
# 18/50 Epoch, Train/Test Loss: 0.0056/0.0670,         Train/Test Accuracy: 0.9982/0.9861,         Elapsed/Remaining time: 9.94/17.68 [min]
# 19/50 Epoch, Train/Test Loss: 0.0007/0.0597,         Train/Test Accuracy: 0.9998/0.9876,         Elapsed/Remaining time: 10.48/17.09 [min]
# 20/50 Epoch, Train/Test Loss: 0.0027/0.0676,         Train/Test Accuracy: 0.9992/0.9873,         Elapsed/Remaining time: 11.01/16.51 [min]
# 21/50 Epoch, Train/Test Loss: 0.0024/0.0659,         Train/Test Accuracy: 0.9992/0.9867,         Elapsed/Remaining time: 11.53/15.93 [min]
# 22/50 Epoch, Train/Test Loss: 0.0012/0.0639,         Train/Test Accuracy: 0.9996/0.9878,         Elapsed/Remaining time: 12.06/15.35 [min]
# 23/50 Epoch, Train/Test Loss: 0.0011/0.0737,         Train/Test Accuracy: 0.9998/0.9883,         Elapsed/Remaining time: 12.60/14.79 [min]
# 24/50 Epoch, Train/Test Loss: 0.0029/0.0654,         Train/Test Accuracy: 0.9991/0.9882,         Elapsed/Remaining time: 13.13/14.22 [min]
# 25/50 Epoch, Train/Test Loss: 0.0011/0.0631,         Train/Test Accuracy: 0.9997/0.9880,         Elapsed/Remaining time: 13.66/13.66 [min]
# 26/50 Epoch, Train/Test Loss: 0.0003/0.0635,         Train/Test Accuracy: 0.9999/0.9882,         Elapsed/Remaining time: 14.19/13.10 [min]
# 27/50 Epoch, Train/Test Loss: 0.0001/0.0609,         Train/Test Accuracy: 1.0000/0.9879,         Elapsed/Remaining time: 14.71/12.53 [min]
# 28/50 Epoch, Train/Test Loss: 0.0000/0.0608,         Train/Test Accuracy: 1.0000/0.9891,         Elapsed/Remaining time: 15.24/11.97 [min]
# 29/50 Epoch, Train/Test Loss: 0.0000/0.0611,         Train/Test Accuracy: 1.0000/0.9894,         Elapsed/Remaining time: 15.77/11.42 [min]
# 30/50 Epoch, Train/Test Loss: 0.0000/0.0613,         Train/Test Accuracy: 1.0000/0.9897,         Elapsed/Remaining time: 16.31/10.87 [min]
# 31/50 Epoch, Train/Test Loss: 0.0000/0.0617,         Train/Test Accuracy: 1.0000/0.9898,         Elapsed/Remaining time: 16.84/10.32 [min]
# 32/50 Epoch, Train/Test Loss: 0.0000/0.0619,         Train/Test Accuracy: 1.0000/0.9898,         Elapsed/Remaining time: 17.36/9.77 [min]
# 33/50 Epoch, Train/Test Loss: 0.0000/0.0622,         Train/Test Accuracy: 1.0000/0.9898,         Elapsed/Remaining time: 17.90/9.22 [min]
# 34/50 Epoch, Train/Test Loss: 0.0000/0.0626,         Train/Test Accuracy: 1.0000/0.9898,         Elapsed/Remaining time: 18.47/8.69 [min]
# 35/50 Epoch, Train/Test Loss: 0.0000/0.0630,         Train/Test Accuracy: 1.0000/0.9898,         Elapsed/Remaining time: 19.00/8.14 [min]
# 36/50 Epoch, Train/Test Loss: 0.0000/0.0636,         Train/Test Accuracy: 1.0000/0.9897,         Elapsed/Remaining time: 19.54/7.60 [min]
# 37/50 Epoch, Train/Test Loss: 0.0000/0.0640,         Train/Test Accuracy: 1.0000/0.9897,         Elapsed/Remaining time: 20.07/7.05 [min]
# 38/50 Epoch, Train/Test Loss: 0.0000/0.0646,         Train/Test Accuracy: 1.0000/0.9897,         Elapsed/Remaining time: 20.60/6.51 [min]
# 39/50 Epoch, Train/Test Loss: 0.0000/0.0651,         Train/Test Accuracy: 1.0000/0.9894,         Elapsed/Remaining time: 21.13/5.96 [min]
# 40/50 Epoch, Train/Test Loss: 0.0000/0.0658,         Train/Test Accuracy: 1.0000/0.9894,         Elapsed/Remaining time: 21.66/5.42 [min]
# 41/50 Epoch, Train/Test Loss: 0.0000/0.0664,         Train/Test Accuracy: 1.0000/0.9894,         Elapsed/Remaining time: 22.21/4.87 [min]
# 42/50 Epoch, Train/Test Loss: 0.0000/0.0671,         Train/Test Accuracy: 1.0000/0.9895,         Elapsed/Remaining time: 22.75/4.33 [min]
# 43/50 Epoch, Train/Test Loss: 0.0000/0.0677,         Train/Test Accuracy: 1.0000/0.9897,         Elapsed/Remaining time: 23.28/3.79 [min]
# 44/50 Epoch, Train/Test Loss: 0.0000/0.0684,         Train/Test Accuracy: 1.0000/0.9897,         Elapsed/Remaining time: 23.84/3.25 [min]
# 45/50 Epoch, Train/Test Loss: 0.0000/0.0691,         Train/Test Accuracy: 1.0000/0.9900,         Elapsed/Remaining time: 24.37/2.71 [min]
# 46/50 Epoch, Train/Test Loss: 0.0000/0.0698,         Train/Test Accuracy: 1.0000/0.9900,         Elapsed/Remaining time: 24.89/2.16 [min]
# 47/50 Epoch, Train/Test Loss: 0.0000/0.0706,         Train/Test Accuracy: 1.0000/0.9901,         Elapsed/Remaining time: 25.42/1.62 [min]
# 48/50 Epoch, Train/Test Loss: 0.0000/0.0714,         Train/Test Accuracy: 1.0000/0.9901,         Elapsed/Remaining time: 25.96/1.08 [min]
# 49/50 Epoch, Train/Test Loss: 0.0000/0.0721,         Train/Test Accuracy: 1.0000/0.9902,         Elapsed/Remaining time: 26.51/0.54 [min]
# 50/50 Epoch, Train/Test Loss: 0.0000/0.0729,         Train/Test Accuracy: 1.0000/0.9903,         Elapsed/Remaining time: 27.04/0.00 [min]

# %%
# Save result
torch.save(model.state_dict(), os.path.join(out, 'final_model.pt'))

np.savez(os.path.join(out, 'log.npz'), **trainer.log)

# %%
# Plot and save log figures
log = np.load(os.path.join(out, 'log.npz'))
bd.plot_util.plot_training_logs(log, out)

# %% [markdown]
# ## 検証

# %%
val_model = net.CNV()
dummy_input = torch.Tensor(np.zeros((1, 1, 28, 28)).astype(np.float32))
val_model(dummy_input)
val_model.load_state_dict(torch.load(os.path.join(out, 'best_model.pt')))
val_model = val_model.eval()

evaluator = bd.Evaluator(val_model, 10, device=device)

# %%
# Evaluation against clean dataset
ret = evaluator.run(
    test_dl,
    out=os.path.join(out, 'clean_test'),
    cmap='Blues',
    fmt='d',
    annot=True,
    cbar=False
)
# Out:
# Accuracy: 0.9903

# %%
# Evaluation against poison dataset
ret = evaluator.run(
    test_p_dl,
    out=os.path.join(out, 'poison_test'),
    cmap='Blues',
    fmt='d',
    annot=True,
    cbar=False
)
# Out:
# Accuracy: 0.9906375390102541
