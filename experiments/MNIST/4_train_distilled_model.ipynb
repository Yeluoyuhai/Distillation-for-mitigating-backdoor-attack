# %%
import os
import numpy as np
import matplotlib.pyplot as plt

import torch
import torchvision
from torchvision import transforms
import ignite
from ignite.engine import create_supervised_evaluator

import backdoor_attack as bd
import backdoor_attack.plot_util
import net

# %%
# result output folder
out = os.path.join('results', 'distilled_model')
os.makedirs(os.path.join(out), exist_ok=True)

# device setup
if torch.cuda.is_available():
    device = torch.device(type='cuda', index=1)
else:
    device = torch.device(type='cpu')

# %% [markdown]
# ## データセットの準備

# %%
transform = transforms.Compose([
    transforms.ToTensor()
])

# %%
ds_root = os.path.join('.', 'results', 'datasets')
tr = np.load(os.path.join(ds_root, 'distillation_training_dataset.npz'))
train_ds = bd.Dataset_from_array(x=tr['x'], t=tr['t'], transform=transform)
te = np.load(os.path.join(ds_root, 'clean_test_dataset.npz'))
test_ds = bd.Dataset_from_array(x=te['x'], t=te['t'], transform=transform)
te_p = np.load(os.path.join(ds_root, 'poison_test_dataset.npz'))
test_p_ds = bd.Dataset_from_array(x=te_p['x'], t=te_p['t_correct'], transform=transform)

train_dl = torch.utils.data.DataLoader(train_ds, batch_size=128, shuffle=True)
test_dl = torch.utils.data.DataLoader(test_ds, batch_size=128, shuffle=False)
test_p_dl = torch.utils.data.DataLoader(test_p_ds, batch_size=128, shuffle=False)

# %% [markdown]
# ## モデルの準備

# %%
teacher_path = os.path.join('results', 'backdoor_model')
teacher_model = net.CNV()
dummy_input = torch.Tensor(np.zeros((1, 1, 28, 28)).astype(np.float32))
teacher_model(dummy_input)
teacher_model.load_state_dict(torch.load(os.path.join(teacher_path, 'model.pt')))
teacher_model = teacher_model.eval()

student_model = net.CNV()
_ = student_model(dummy_input)

# %% [markdown]
# ## 学習

# %%
trainer = bd.distillation.Distillator(train_dl, test_dl, teacher_model, student_model, device)
optimizer = torch.optim.Adam
epoch = 50

# when the training epoch achieved any temp['epoch'], 
# the temperature is update to corresponding value
temp = {
    'epoch': np.array([0, 20, 40]),
    't': np.array([20, 10, 5]),
}

trainer.run(optimizer, epoch, temp)
# Out:
# 1/50 Epoch, Train/Test Loss: 0.7168/0.7410,         Train/Test Accuracy: 0.9237/0.9258,         Temperature: tensor([20], device='cuda:1'),         Elapsed/Remaining time: 0.03/1.28 [min]
# 2/50 Epoch, Train/Test Loss: 0.2595/0.2790,         Train/Test Accuracy: 0.9666/0.9651,         Temperature: tensor([20], device='cuda:1'),         Elapsed/Remaining time: 0.05/1.31 [min]
# 3/50 Epoch, Train/Test Loss: 0.1483/0.1691,         Train/Test Accuracy: 0.9800/0.9757,         Temperature: tensor([20], device='cuda:1'),         Elapsed/Remaining time: 0.08/1.31 [min]
# 4/50 Epoch, Train/Test Loss: 0.1136/0.1340,         Train/Test Accuracy: 0.9848/0.9797,         Temperature: tensor([20], device='cuda:1'),         Elapsed/Remaining time: 0.11/1.31 [min]
# 5/50 Epoch, Train/Test Loss: 0.0980/0.1134,         Train/Test Accuracy: 0.9875/0.9825,         Temperature: tensor([20], device='cuda:1'),         Elapsed/Remaining time: 0.14/1.29 [min]
# 6/50 Epoch, Train/Test Loss: 0.0898/0.1150,         Train/Test Accuracy: 0.9880/0.9832,         Temperature: tensor([20], device='cuda:1'),         Elapsed/Remaining time: 0.17/1.26 [min]
# 7/50 Epoch, Train/Test Loss: 0.0832/0.1020,         Train/Test Accuracy: 0.9897/0.9843,         Temperature: tensor([20], device='cuda:1'),         Elapsed/Remaining time: 0.20/1.24 [min]
# 8/50 Epoch, Train/Test Loss: 0.0801/0.1026,         Train/Test Accuracy: 0.9896/0.9844,         Temperature: tensor([20], device='cuda:1'),         Elapsed/Remaining time: 0.23/1.21 [min]
# 9/50 Epoch, Train/Test Loss: 0.0716/0.0974,         Train/Test Accuracy: 0.9905/0.9850,         Temperature: tensor([20], device='cuda:1'),         Elapsed/Remaining time: 0.26/1.19 [min]
# 10/50 Epoch, Train/Test Loss: 0.0719/0.0935,         Train/Test Accuracy: 0.9898/0.9853,         Temperature: tensor([20], device='cuda:1'),         Elapsed/Remaining time: 0.29/1.18 [min]
# 11/50 Epoch, Train/Test Loss: 0.0710/0.0939,         Train/Test Accuracy: 0.9905/0.9857,         Temperature: tensor([20], device='cuda:1'),         Elapsed/Remaining time: 0.33/1.16 [min]
# 12/50 Epoch, Train/Test Loss: 0.0702/0.0947,         Train/Test Accuracy: 0.9907/0.9860,         Temperature: tensor([20], device='cuda:1'),         Elapsed/Remaining time: 0.35/1.12 [min]
# 13/50 Epoch, Train/Test Loss: 0.0673/0.0865,         Train/Test Accuracy: 0.9914/0.9866,         Temperature: tensor([20], device='cuda:1'),         Elapsed/Remaining time: 0.38/1.09 [min]
# 14/50 Epoch, Train/Test Loss: 0.0659/0.0876,         Train/Test Accuracy: 0.9913/0.9862,         Temperature: tensor([20], device='cuda:1'),         Elapsed/Remaining time: 0.41/1.06 [min]
# 15/50 Epoch, Train/Test Loss: 0.0681/0.0902,         Train/Test Accuracy: 0.9908/0.9862,         Temperature: tensor([20], device='cuda:1'),         Elapsed/Remaining time: 0.44/1.03 [min]
# 16/50 Epoch, Train/Test Loss: 0.0659/0.0906,         Train/Test Accuracy: 0.9909/0.9862,         Temperature: tensor([20], device='cuda:1'),         Elapsed/Remaining time: 0.47/0.99 [min]
# 17/50 Epoch, Train/Test Loss: 0.0672/0.0895,         Train/Test Accuracy: 0.9913/0.9865,         Temperature: tensor([20], device='cuda:1'),         Elapsed/Remaining time: 0.49/0.95 [min]
# 18/50 Epoch, Train/Test Loss: 0.0666/0.0907,         Train/Test Accuracy: 0.9907/0.9866,         Temperature: tensor([20], device='cuda:1'),         Elapsed/Remaining time: 0.52/0.92 [min]
# 19/50 Epoch, Train/Test Loss: 0.0647/0.0878,         Train/Test Accuracy: 0.9910/0.9861,         Temperature: tensor([20], device='cuda:1'),         Elapsed/Remaining time: 0.55/0.89 [min]
# 20/50 Epoch, Train/Test Loss: 0.0659/0.0883,         Train/Test Accuracy: 0.9914/0.9865,         Temperature: tensor([20], device='cuda:1'),         Elapsed/Remaining time: 0.57/0.86 [min]
# 21/50 Epoch, Train/Test Loss: 0.0640/0.0894,         Train/Test Accuracy: 0.9912/0.9867,         Temperature: tensor([10], device='cuda:1'),         Elapsed/Remaining time: 0.60/0.83 [min]
# 22/50 Epoch, Train/Test Loss: 0.0616/0.0871,         Train/Test Accuracy: 0.9914/0.9864,         Temperature: tensor([10], device='cuda:1'),         Elapsed/Remaining time: 0.63/0.80 [min]
# 23/50 Epoch, Train/Test Loss: 0.0626/0.0881,         Train/Test Accuracy: 0.9911/0.9864,         Temperature: tensor([10], device='cuda:1'),         Elapsed/Remaining time: 0.66/0.77 [min]
# 24/50 Epoch, Train/Test Loss: 0.0612/0.0867,         Train/Test Accuracy: 0.9913/0.9866,         Temperature: tensor([10], device='cuda:1'),         Elapsed/Remaining time: 0.68/0.74 [min]
# 25/50 Epoch, Train/Test Loss: 0.0617/0.0874,         Train/Test Accuracy: 0.9915/0.9865,         Temperature: tensor([10], device='cuda:1'),         Elapsed/Remaining time: 0.71/0.71 [min]
# 26/50 Epoch, Train/Test Loss: 0.0626/0.0884,         Train/Test Accuracy: 0.9910/0.9870,         Temperature: tensor([10], device='cuda:1'),         Elapsed/Remaining time: 0.74/0.68 [min]
# 27/50 Epoch, Train/Test Loss: 0.0610/0.0873,         Train/Test Accuracy: 0.9912/0.9866,         Temperature: tensor([10], device='cuda:1'),         Elapsed/Remaining time: 0.76/0.65 [min]
# 28/50 Epoch, Train/Test Loss: 0.0639/0.0874,         Train/Test Accuracy: 0.9916/0.9862,         Temperature: tensor([10], device='cuda:1'),         Elapsed/Remaining time: 0.79/0.62 [min]
# 29/50 Epoch, Train/Test Loss: 0.0639/0.0884,         Train/Test Accuracy: 0.9919/0.9863,         Temperature: tensor([10], device='cuda:1'),         Elapsed/Remaining time: 0.82/0.59 [min]
# 30/50 Epoch, Train/Test Loss: 0.0635/0.0859,         Train/Test Accuracy: 0.9922/0.9870,         Temperature: tensor([10], device='cuda:1'),         Elapsed/Remaining time: 0.84/0.56 [min]
# 31/50 Epoch, Train/Test Loss: 0.0642/0.0860,         Train/Test Accuracy: 0.9911/0.9866,         Temperature: tensor([10], device='cuda:1'),         Elapsed/Remaining time: 0.87/0.53 [min]
# 32/50 Epoch, Train/Test Loss: 0.0645/0.0859,         Train/Test Accuracy: 0.9914/0.9869,         Temperature: tensor([10], device='cuda:1'),         Elapsed/Remaining time: 0.90/0.50 [min]
# 33/50 Epoch, Train/Test Loss: 0.0612/0.0857,         Train/Test Accuracy: 0.9917/0.9869,         Temperature: tensor([10], device='cuda:1'),         Elapsed/Remaining time: 0.93/0.48 [min]
# 34/50 Epoch, Train/Test Loss: 0.0668/0.0890,         Train/Test Accuracy: 0.9914/0.9865,         Temperature: tensor([10], device='cuda:1'),         Elapsed/Remaining time: 0.95/0.45 [min]
# 35/50 Epoch, Train/Test Loss: 0.0634/0.0891,         Train/Test Accuracy: 0.9912/0.9860,         Temperature: tensor([10], device='cuda:1'),         Elapsed/Remaining time: 0.98/0.42 [min]
# 36/50 Epoch, Train/Test Loss: 0.0649/0.0883,         Train/Test Accuracy: 0.9911/0.9864,         Temperature: tensor([10], device='cuda:1'),         Elapsed/Remaining time: 1.01/0.39 [min]
# 37/50 Epoch, Train/Test Loss: 0.0643/0.0870,         Train/Test Accuracy: 0.9916/0.9864,         Temperature: tensor([10], device='cuda:1'),         Elapsed/Remaining time: 1.03/0.36 [min]
# 38/50 Epoch, Train/Test Loss: 0.0686/0.0872,         Train/Test Accuracy: 0.9904/0.9864,         Temperature: tensor([10], device='cuda:1'),         Elapsed/Remaining time: 1.06/0.34 [min]
# 39/50 Epoch, Train/Test Loss: 0.0638/0.0876,         Train/Test Accuracy: 0.9915/0.9870,         Temperature: tensor([10], device='cuda:1'),         Elapsed/Remaining time: 1.09/0.31 [min]
# 40/50 Epoch, Train/Test Loss: 0.0679/0.0886,         Train/Test Accuracy: 0.9908/0.9865,         Temperature: tensor([10], device='cuda:1'),         Elapsed/Remaining time: 1.12/0.28 [min]
# 41/50 Epoch, Train/Test Loss: 0.0715/0.0892,         Train/Test Accuracy: 0.9899/0.9864,         Temperature: tensor([5], device='cuda:1'),         Elapsed/Remaining time: 1.15/0.25 [min]
# 42/50 Epoch, Train/Test Loss: 0.0773/0.0943,         Train/Test Accuracy: 0.9897/0.9865,         Temperature: tensor([5], device='cuda:1'),         Elapsed/Remaining time: 1.18/0.22 [min]
# 43/50 Epoch, Train/Test Loss: 0.0772/0.0850,         Train/Test Accuracy: 0.9900/0.9873,         Temperature: tensor([5], device='cuda:1'),         Elapsed/Remaining time: 1.20/0.20 [min]
# 44/50 Epoch, Train/Test Loss: 0.0768/0.0889,         Train/Test Accuracy: 0.9903/0.9867,         Temperature: tensor([5], device='cuda:1'),         Elapsed/Remaining time: 1.23/0.17 [min]
# 45/50 Epoch, Train/Test Loss: 0.0810/0.0891,         Train/Test Accuracy: 0.9902/0.9871,         Temperature: tensor([5], device='cuda:1'),         Elapsed/Remaining time: 1.26/0.14 [min]
# 46/50 Epoch, Train/Test Loss: 0.0756/0.0846,         Train/Test Accuracy: 0.9910/0.9869,         Temperature: tensor([5], device='cuda:1'),         Elapsed/Remaining time: 1.30/0.11 [min]
# 47/50 Epoch, Train/Test Loss: 0.0736/0.0864,         Train/Test Accuracy: 0.9909/0.9875,         Temperature: tensor([5], device='cuda:1'),         Elapsed/Remaining time: 1.32/0.08 [min]
# 48/50 Epoch, Train/Test Loss: 0.0779/0.0880,         Train/Test Accuracy: 0.9903/0.9865,         Temperature: tensor([5], device='cuda:1'),         Elapsed/Remaining time: 1.35/0.06 [min]
# 49/50 Epoch, Train/Test Loss: 0.0713/0.0835,         Train/Test Accuracy: 0.9903/0.9869,         Temperature: tensor([5], device='cuda:1'),         Elapsed/Remaining time: 1.38/0.03 [min]
# 50/50 Epoch, Train/Test Loss: 0.0717/0.0844,         Train/Test Accuracy: 0.9905/0.9878,         Temperature: tensor([5], device='cuda:1'),         Elapsed/Remaining time: 1.41/0.00 [min]

# %%
# Save result
torch.save(student_model.state_dict(), os.path.join(out, 'model.pt'))

np.savez(os.path.join(out, 'log.npz'), **trainer.log)

# %%
# Plot and save log figures
log = np.load(os.path.join(out, 'log.npz'))
bd.plot_util.plot_training_logs(log, out)

# %% [markdown]
# ## 検証

# %%
val_model = net.CNV()
dummy_input = torch.Tensor(np.zeros((1, 1, 28, 28)).astype(np.float32))
val_model(dummy_input)
val_model.load_state_dict(torch.load(os.path.join(out, 'model.pt')))
val_model = val_model.eval()

evaluator = bd.Evaluator(val_model, 10, device=device)

# %%
# Evaluation against clean dataset
ret = evaluator.run(
    test_dl,
    out=os.path.join(out, 'clean_confmat.png'),
    cmap='Blues',
    fmt='d',
    annot=True,
    cbar=False
)
# Out:
# Accuracy: 0.9878

# %%
# Evaluation against poison dataset
ret = evaluator.run(
    test_p_dl,
    out=os.path.join(out, 'poison_confmat.png'),
    cmap='Blues',
    fmt='d',
    annot=True,
    cbar=False
)
# Out:
# Accuracy: 0.9865135978600089
