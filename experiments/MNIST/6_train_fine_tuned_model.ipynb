# %%
import os
import numpy as np
import matplotlib.pyplot as plt

import torch
import torchvision
from torchvision import transforms
import ignite
from ignite.engine import create_supervised_evaluator

import backdoor_attack as bd
import backdoor_attack.plot_util
import net

# %%
# result output folder
out = os.path.join('results', 'fine_tuned_model')
os.makedirs(os.path.join(out), exist_ok=True)

# device setup
if torch.cuda.is_available():
    device = torch.device(type='cuda', index=1)
else:
    device = torch.device(type='cpu')

# %% [markdown]
# ## データセットの準備

# %%
transform = transforms.Compose([
    transforms.ToTensor()
])

# %%
ds_root = os.path.join('.', 'results', 'datasets')
tr = np.load(os.path.join('.', 'results', 'screening', 'screening_negative_dataset.npz'))
train_ds = bd.Dataset_from_array(x=tr['x'], t=tr['t'], transform=transform)
te = np.load(os.path.join(ds_root, 'clean_test_dataset.npz'))
test_ds = bd.Dataset_from_array(x=te['x'], t=te['t'], transform=transform)
te_p = np.load(os.path.join(ds_root, 'poison_test_dataset.npz'))
test_p_ds = bd.Dataset_from_array(x=te_p['x'], t=te_p['t_correct'], transform=transform)

train_dl = torch.utils.data.DataLoader(train_ds, batch_size=128, shuffle=True)
test_dl = torch.utils.data.DataLoader(test_ds, batch_size=128, shuffle=False)
test_p_dl = torch.utils.data.DataLoader(test_p_ds, batch_size=128, shuffle=False)

# %% [markdown]
# ## モデルの準備

# %%
model = net.CNV()
dummy_input = torch.Tensor(np.zeros((1, 1, 28, 28)).astype(np.float32))
model(dummy_input)
model.load_state_dict(torch.load(os.path.join('results', 'distilled_model', 'model.pt')))
model = model.eval()

# %%
trainer = bd.Trainer(train_dl, test_dl, model, device)
optimizer = torch.optim.Adam
epoch = 50

trainer.run(optimizer, epoch)
# Out:
# 1/50 Epoch, Train/Test Loss: 0.0124/0.0619,         Train/Test Accuracy: 0.9958/0.9850,         Elapsed/Remaining time: 0.10/5.04 [min]
# 2/50 Epoch, Train/Test Loss: 0.0053/0.0550,         Train/Test Accuracy: 0.9984/0.9867,         Elapsed/Remaining time: 0.19/4.50 [min]
# 3/50 Epoch, Train/Test Loss: 0.0060/0.0682,         Train/Test Accuracy: 0.9978/0.9853,         Elapsed/Remaining time: 0.29/4.60 [min]
# 4/50 Epoch, Train/Test Loss: 0.0088/0.0754,         Train/Test Accuracy: 0.9970/0.9836,         Elapsed/Remaining time: 0.39/4.50 [min]
# 5/50 Epoch, Train/Test Loss: 0.0020/0.0729,         Train/Test Accuracy: 0.9992/0.9861,         Elapsed/Remaining time: 0.50/4.47 [min]
# 6/50 Epoch, Train/Test Loss: 0.0033/0.0681,         Train/Test Accuracy: 0.9990/0.9863,         Elapsed/Remaining time: 0.61/4.50 [min]
# 7/50 Epoch, Train/Test Loss: 0.0006/0.0606,         Train/Test Accuracy: 0.9997/0.9882,         Elapsed/Remaining time: 0.73/4.50 [min]
# 8/50 Epoch, Train/Test Loss: 0.0030/0.0727,         Train/Test Accuracy: 0.9993/0.9865,         Elapsed/Remaining time: 0.85/4.46 [min]
# 9/50 Epoch, Train/Test Loss: 0.0091/0.0823,         Train/Test Accuracy: 0.9972/0.9848,         Elapsed/Remaining time: 0.95/4.34 [min]
# 10/50 Epoch, Train/Test Loss: 0.0025/0.0644,         Train/Test Accuracy: 0.9992/0.9873,         Elapsed/Remaining time: 1.07/4.28 [min]
# 11/50 Epoch, Train/Test Loss: 0.0023/0.0673,         Train/Test Accuracy: 0.9991/0.9864,         Elapsed/Remaining time: 1.18/4.17 [min]
# 12/50 Epoch, Train/Test Loss: 0.0007/0.0648,         Train/Test Accuracy: 0.9998/0.9896,         Elapsed/Remaining time: 1.28/4.05 [min]
# 13/50 Epoch, Train/Test Loss: 0.0005/0.0673,         Train/Test Accuracy: 0.9998/0.9883,         Elapsed/Remaining time: 1.38/3.92 [min]
# 14/50 Epoch, Train/Test Loss: 0.0002/0.0616,         Train/Test Accuracy: 0.9999/0.9892,         Elapsed/Remaining time: 1.48/3.80 [min]
# 15/50 Epoch, Train/Test Loss: 0.0001/0.0716,         Train/Test Accuracy: 1.0000/0.9885,         Elapsed/Remaining time: 1.57/3.66 [min]
# 16/50 Epoch, Train/Test Loss: 0.0000/0.0689,         Train/Test Accuracy: 1.0000/0.9896,         Elapsed/Remaining time: 1.67/3.54 [min]
# 17/50 Epoch, Train/Test Loss: 0.0000/0.0693,         Train/Test Accuracy: 1.0000/0.9896,         Elapsed/Remaining time: 1.78/3.46 [min]
# 18/50 Epoch, Train/Test Loss: 0.0000/0.0698,         Train/Test Accuracy: 1.0000/0.9895,         Elapsed/Remaining time: 1.88/3.34 [min]
# 19/50 Epoch, Train/Test Loss: 0.0000/0.0703,         Train/Test Accuracy: 1.0000/0.9896,         Elapsed/Remaining time: 1.97/3.22 [min]
# 20/50 Epoch, Train/Test Loss: 0.0000/0.0708,         Train/Test Accuracy: 1.0000/0.9897,         Elapsed/Remaining time: 2.07/3.10 [min]
# 21/50 Epoch, Train/Test Loss: 0.0000/0.0713,         Train/Test Accuracy: 1.0000/0.9897,         Elapsed/Remaining time: 2.16/2.99 [min]
# 22/50 Epoch, Train/Test Loss: 0.0000/0.0718,         Train/Test Accuracy: 1.0000/0.9897,         Elapsed/Remaining time: 2.25/2.87 [min]
# 23/50 Epoch, Train/Test Loss: 0.0000/0.0724,         Train/Test Accuracy: 1.0000/0.9897,         Elapsed/Remaining time: 2.35/2.76 [min]
# 24/50 Epoch, Train/Test Loss: 0.0000/0.0729,         Train/Test Accuracy: 1.0000/0.9897,         Elapsed/Remaining time: 2.44/2.64 [min]
# 25/50 Epoch, Train/Test Loss: 0.0000/0.0733,         Train/Test Accuracy: 1.0000/0.9896,         Elapsed/Remaining time: 2.53/2.53 [min]
# 26/50 Epoch, Train/Test Loss: 0.0000/0.0741,         Train/Test Accuracy: 1.0000/0.9897,         Elapsed/Remaining time: 2.62/2.42 [min]
# 27/50 Epoch, Train/Test Loss: 0.0000/0.0746,         Train/Test Accuracy: 1.0000/0.9895,         Elapsed/Remaining time: 2.71/2.31 [min]
# 28/50 Epoch, Train/Test Loss: 0.0000/0.0751,         Train/Test Accuracy: 1.0000/0.9895,         Elapsed/Remaining time: 2.81/2.21 [min]
# 29/50 Epoch, Train/Test Loss: 0.0000/0.0758,         Train/Test Accuracy: 1.0000/0.9897,         Elapsed/Remaining time: 2.90/2.10 [min]
# 30/50 Epoch, Train/Test Loss: 0.0000/0.0763,         Train/Test Accuracy: 1.0000/0.9898,         Elapsed/Remaining time: 3.00/2.00 [min]
# 31/50 Epoch, Train/Test Loss: 0.0000/0.0769,         Train/Test Accuracy: 1.0000/0.9898,         Elapsed/Remaining time: 3.10/1.90 [min]
# 32/50 Epoch, Train/Test Loss: 0.0000/0.0774,         Train/Test Accuracy: 1.0000/0.9899,         Elapsed/Remaining time: 3.19/1.79 [min]
# 33/50 Epoch, Train/Test Loss: 0.0000/0.0782,         Train/Test Accuracy: 1.0000/0.9900,         Elapsed/Remaining time: 3.29/1.69 [min]
# 34/50 Epoch, Train/Test Loss: 0.0000/0.0787,         Train/Test Accuracy: 1.0000/0.9900,         Elapsed/Remaining time: 3.40/1.60 [min]
# 35/50 Epoch, Train/Test Loss: 0.0000/0.0793,         Train/Test Accuracy: 1.0000/0.9899,         Elapsed/Remaining time: 3.52/1.51 [min]
# 36/50 Epoch, Train/Test Loss: 0.0000/0.0796,         Train/Test Accuracy: 1.0000/0.9899,         Elapsed/Remaining time: 3.63/1.41 [min]
# 37/50 Epoch, Train/Test Loss: 0.0000/0.0802,         Train/Test Accuracy: 1.0000/0.9898,         Elapsed/Remaining time: 3.75/1.32 [min]
# 38/50 Epoch, Train/Test Loss: 0.0000/0.0808,         Train/Test Accuracy: 1.0000/0.9898,         Elapsed/Remaining time: 3.86/1.22 [min]
# 39/50 Epoch, Train/Test Loss: 0.0000/0.0815,         Train/Test Accuracy: 1.0000/0.9896,         Elapsed/Remaining time: 3.98/1.12 [min]
# 40/50 Epoch, Train/Test Loss: 0.0000/0.0820,         Train/Test Accuracy: 1.0000/0.9896,         Elapsed/Remaining time: 4.09/1.02 [min]
# 41/50 Epoch, Train/Test Loss: 0.0000/0.0826,         Train/Test Accuracy: 1.0000/0.9896,         Elapsed/Remaining time: 4.20/0.92 [min]
# 42/50 Epoch, Train/Test Loss: 0.0000/0.0831,         Train/Test Accuracy: 1.0000/0.9896,         Elapsed/Remaining time: 4.32/0.82 [min]
# 43/50 Epoch, Train/Test Loss: 0.0000/0.0836,         Train/Test Accuracy: 1.0000/0.9897,         Elapsed/Remaining time: 4.44/0.72 [min]
# 44/50 Epoch, Train/Test Loss: 0.0000/0.0839,         Train/Test Accuracy: 1.0000/0.9898,         Elapsed/Remaining time: 4.55/0.62 [min]
# 45/50 Epoch, Train/Test Loss: 0.0000/0.0843,         Train/Test Accuracy: 1.0000/0.9899,         Elapsed/Remaining time: 4.67/0.52 [min]
# 46/50 Epoch, Train/Test Loss: 0.0000/0.0846,         Train/Test Accuracy: 1.0000/0.9898,         Elapsed/Remaining time: 4.79/0.42 [min]
# 47/50 Epoch, Train/Test Loss: 0.0000/0.0848,         Train/Test Accuracy: 1.0000/0.9898,         Elapsed/Remaining time: 4.90/0.31 [min]
# 48/50 Epoch, Train/Test Loss: 0.0000/0.0851,         Train/Test Accuracy: 1.0000/0.9897,         Elapsed/Remaining time: 5.00/0.21 [min]
# 49/50 Epoch, Train/Test Loss: 0.0000/0.0852,         Train/Test Accuracy: 1.0000/0.9897,         Elapsed/Remaining time: 5.09/0.10 [min]
# 50/50 Epoch, Train/Test Loss: 0.0000/0.0854,         Train/Test Accuracy: 1.0000/0.9899,         Elapsed/Remaining time: 5.19/0.00 [min]

# %%
# Save result
torch.save(model.state_dict(), os.path.join(out, 'model.pt'))

np.savez(os.path.join(out, 'log.npz'), **trainer.log)

# %%
# Plot and save log figures
log = np.load(os.path.join(out, 'log.npz'))
bd.plot_util.plot_training_logs(log, out)

# %% [markdown]
# ## 検証

# %%
val_model = net.CNV()
dummy_input = torch.Tensor(np.zeros((1, 1, 28, 28)).astype(np.float32))
val_model(dummy_input)
val_model.load_state_dict(torch.load(os.path.join(out, 'model.pt')))
val_model = val_model.eval()

evaluator = bd.Evaluator(val_model, 10, device=device)

# %%
# Evaluation against clean dataset
ret = evaluator.run(
    test_dl,
    out=out,
    cmap='Blues',
    fmt='d',
    annot=True,
    cbar=False
)
# Out:
# Accuracy: 0.9899

# %%
# Evaluation against poison dataset
ret = evaluator.run(
    test_p_dl,
    out=out,
    cmap='Blues',
    fmt='d',
    annot=True,
    cbar=False
)
# Out:
# Accuracy: 0.9900802496656264
