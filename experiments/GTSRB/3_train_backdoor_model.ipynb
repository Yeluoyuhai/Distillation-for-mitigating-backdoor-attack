# %%
import os
import numpy as np
import matplotlib.pyplot as plt

import torch
import torchvision
from torchvision import transforms
import ignite
from ignite.engine import create_supervised_evaluator

import backdoor_attack as bd
import backdoor_attack.plot_util
import net

torch.manual_seed(20200705)

# %%
# result output folder
out = os.path.join('results', 'backdoor_model')
os.makedirs(os.path.join(out), exist_ok=True)

# device setup
if torch.cuda.is_available():
    device = torch.device(type='cuda', index=1)
else:
    device = torch.device(type='cpu')

# %% [markdown]
# ## データセットの準備

# %%
transform = transforms.Compose([
    transforms.ToTensor()
])

# %%
ds_root = os.path.join('.', 'results', 'datasets')
tr = np.load(os.path.join(ds_root, 'poison_training_dataset.npz'))
train_ds = bd.Dataset_from_array(x=tr['x'], t=tr['t'], transform=transform)
te = np.load(os.path.join(ds_root, 'clean_test_dataset.npz'))
test_ds = bd.Dataset_from_array(x=te['x'], t=te['t'], transform=transform)
te_p = np.load(os.path.join(ds_root, 'poison_test_dataset.npz'))
test_p_ds = bd.Dataset_from_array(x=te_p['x'], t=te_p['t_correct'], transform=transform)

train_dl = torch.utils.data.DataLoader(train_ds, batch_size=128, shuffle=True)
test_dl = torch.utils.data.DataLoader(test_ds, batch_size=128, shuffle=False)
test_p_dl = torch.utils.data.DataLoader(test_p_ds, batch_size=128, shuffle=False)

# %% [markdown]
# ## モデルの準備

# %%
model = net.CNV()
dummy_input = torch.Tensor(np.zeros((1, 3, 32, 32)).astype(np.float32))
_ = model(dummy_input)

# %% [markdown]
# ## 学習

# %%
trainer = bd.Trainer(train_dl, test_dl, model, device)
optimizer = torch.optim.Adam
epoch = 50

trainer.run(optimizer, epoch, out)
# Out:
# 1/50 Epoch, Train/Test Loss: 2.5204/2.5827,         Train/Test Accuracy: 0.2017/0.2116,         Elapsed/Remaining time: 0.28/13.89 [min]
# 2/50 Epoch, Train/Test Loss: 0.9970/1.1370,         Train/Test Accuracy: 0.6549/0.6271,         Elapsed/Remaining time: 0.60/14.40 [min]
# 3/50 Epoch, Train/Test Loss: 0.2831/0.4657,         Train/Test Accuracy: 0.9119/0.8695,         Elapsed/Remaining time: 0.91/14.29 [min]
# 4/50 Epoch, Train/Test Loss: 0.1388/0.3807,         Train/Test Accuracy: 0.9557/0.9061,         Elapsed/Remaining time: 1.22/14.09 [min]
# 5/50 Epoch, Train/Test Loss: 0.0949/0.2973,         Train/Test Accuracy: 0.9724/0.9188,         Elapsed/Remaining time: 1.55/13.91 [min]
# 6/50 Epoch, Train/Test Loss: 0.0846/0.3149,         Train/Test Accuracy: 0.9773/0.9242,         Elapsed/Remaining time: 1.86/13.67 [min]
# 7/50 Epoch, Train/Test Loss: 0.0590/0.3199,         Train/Test Accuracy: 0.9828/0.9324,         Elapsed/Remaining time: 2.19/13.43 [min]
# 8/50 Epoch, Train/Test Loss: 0.1799/0.4280,         Train/Test Accuracy: 0.9599/0.9082,         Elapsed/Remaining time: 2.46/12.90 [min]
# 9/50 Epoch, Train/Test Loss: 0.0717/0.3170,         Train/Test Accuracy: 0.9806/0.9325,         Elapsed/Remaining time: 2.78/12.67 [min]
# 10/50 Epoch, Train/Test Loss: 0.1028/0.4115,         Train/Test Accuracy: 0.9801/0.9255,         Elapsed/Remaining time: 3.05/12.20 [min]
# 11/50 Epoch, Train/Test Loss: 0.0377/0.2952,         Train/Test Accuracy: 0.9919/0.9406,         Elapsed/Remaining time: 3.37/11.95 [min]
# 12/50 Epoch, Train/Test Loss: 0.0551/0.3555,         Train/Test Accuracy: 0.9863/0.9386,         Elapsed/Remaining time: 3.65/11.56 [min]
# 13/50 Epoch, Train/Test Loss: 0.0877/0.4393,         Train/Test Accuracy: 0.9846/0.9356,         Elapsed/Remaining time: 3.93/11.20 [min]
# 14/50 Epoch, Train/Test Loss: 0.0695/0.3656,         Train/Test Accuracy: 0.9803/0.9275,         Elapsed/Remaining time: 4.22/10.84 [min]
# 15/50 Epoch, Train/Test Loss: 0.1029/0.5297,         Train/Test Accuracy: 0.9771/0.9158,         Elapsed/Remaining time: 4.50/10.49 [min]
# 16/50 Epoch, Train/Test Loss: 0.1252/0.4437,         Train/Test Accuracy: 0.9722/0.9102,         Elapsed/Remaining time: 4.77/10.13 [min]
# 17/50 Epoch, Train/Test Loss: 0.0705/0.4380,         Train/Test Accuracy: 0.9865/0.9340,         Elapsed/Remaining time: 5.03/9.77 [min]
# 18/50 Epoch, Train/Test Loss: 0.0252/0.2764,         Train/Test Accuracy: 0.9937/0.9435,         Elapsed/Remaining time: 5.36/9.52 [min]
# 19/50 Epoch, Train/Test Loss: 0.0591/0.4322,         Train/Test Accuracy: 0.9870/0.9236,         Elapsed/Remaining time: 5.62/9.18 [min]
# 20/50 Epoch, Train/Test Loss: 0.0180/0.3654,         Train/Test Accuracy: 0.9957/0.9405,         Elapsed/Remaining time: 5.89/8.84 [min]
# 21/50 Epoch, Train/Test Loss: 0.1661/0.5693,         Train/Test Accuracy: 0.9825/0.9230,         Elapsed/Remaining time: 6.16/8.51 [min]
# 22/50 Epoch, Train/Test Loss: 0.0489/0.4539,         Train/Test Accuracy: 0.9898/0.9344,         Elapsed/Remaining time: 6.43/8.18 [min]
# 23/50 Epoch, Train/Test Loss: 0.0193/0.3483,         Train/Test Accuracy: 0.9951/0.9424,         Elapsed/Remaining time: 6.70/7.86 [min]
# 24/50 Epoch, Train/Test Loss: 0.0354/0.4619,         Train/Test Accuracy: 0.9934/0.9402,         Elapsed/Remaining time: 6.97/7.55 [min]
# 25/50 Epoch, Train/Test Loss: 0.3528/0.6633,         Train/Test Accuracy: 0.9231/0.8605,         Elapsed/Remaining time: 7.23/7.23 [min]
# 26/50 Epoch, Train/Test Loss: 0.0992/0.4452,         Train/Test Accuracy: 0.9761/0.9120,         Elapsed/Remaining time: 7.50/6.93 [min]
# 27/50 Epoch, Train/Test Loss: 0.0396/0.5162,         Train/Test Accuracy: 0.9898/0.9337,         Elapsed/Remaining time: 7.77/6.62 [min]
# 28/50 Epoch, Train/Test Loss: 0.0740/0.4136,         Train/Test Accuracy: 0.9823/0.9244,         Elapsed/Remaining time: 8.04/6.32 [min]
# 29/50 Epoch, Train/Test Loss: 0.0216/0.3404,         Train/Test Accuracy: 0.9940/0.9446,         Elapsed/Remaining time: 8.36/6.05 [min]
# 30/50 Epoch, Train/Test Loss: 0.0854/0.4107,         Train/Test Accuracy: 0.9844/0.9293,         Elapsed/Remaining time: 8.63/5.75 [min]
# 31/50 Epoch, Train/Test Loss: 0.0348/0.4489,         Train/Test Accuracy: 0.9930/0.9367,         Elapsed/Remaining time: 8.90/5.45 [min]
# 32/50 Epoch, Train/Test Loss: 0.0131/0.3454,         Train/Test Accuracy: 0.9965/0.9430,         Elapsed/Remaining time: 9.17/5.16 [min]
# 33/50 Epoch, Train/Test Loss: 0.0603/0.3906,         Train/Test Accuracy: 0.9885/0.9325,         Elapsed/Remaining time: 9.43/4.86 [min]
# 34/50 Epoch, Train/Test Loss: 0.1532/0.5774,         Train/Test Accuracy: 0.9698/0.9031,         Elapsed/Remaining time: 9.70/4.57 [min]
# 35/50 Epoch, Train/Test Loss: 0.0738/0.3665,         Train/Test Accuracy: 0.9874/0.9346,         Elapsed/Remaining time: 9.97/4.27 [min]
# 36/50 Epoch, Train/Test Loss: 0.0194/0.4419,         Train/Test Accuracy: 0.9955/0.9424,         Elapsed/Remaining time: 10.24/3.98 [min]
# 37/50 Epoch, Train/Test Loss: 0.0161/0.4165,         Train/Test Accuracy: 0.9974/0.9484,         Elapsed/Remaining time: 10.56/3.71 [min]
# 38/50 Epoch, Train/Test Loss: 0.0249/0.4063,         Train/Test Accuracy: 0.9945/0.9405,         Elapsed/Remaining time: 10.84/3.42 [min]
# 39/50 Epoch, Train/Test Loss: 0.0122/0.5388,         Train/Test Accuracy: 0.9979/0.9432,         Elapsed/Remaining time: 11.12/3.14 [min]
# 40/50 Epoch, Train/Test Loss: 0.1121/0.7697,         Train/Test Accuracy: 0.9768/0.9143,         Elapsed/Remaining time: 11.40/2.85 [min]
# 41/50 Epoch, Train/Test Loss: 0.0501/0.9253,         Train/Test Accuracy: 0.9921/0.9258,         Elapsed/Remaining time: 11.68/2.56 [min]
# 42/50 Epoch, Train/Test Loss: 0.0223/0.9937,         Train/Test Accuracy: 0.9954/0.9335,         Elapsed/Remaining time: 11.96/2.28 [min]
# 43/50 Epoch, Train/Test Loss: 0.0091/1.2762,         Train/Test Accuracy: 0.9983/0.9476,         Elapsed/Remaining time: 12.23/1.99 [min]
# 44/50 Epoch, Train/Test Loss: 0.3013/0.6587,         Train/Test Accuracy: 0.9325/0.8538,         Elapsed/Remaining time: 12.50/1.70 [min]
# 45/50 Epoch, Train/Test Loss: 0.0347/0.4697,         Train/Test Accuracy: 0.9938/0.9323,         Elapsed/Remaining time: 12.77/1.42 [min]
# 46/50 Epoch, Train/Test Loss: 0.0357/0.5235,         Train/Test Accuracy: 0.9934/0.9337,         Elapsed/Remaining time: 13.03/1.13 [min]
# 47/50 Epoch, Train/Test Loss: 0.0260/0.4806,         Train/Test Accuracy: 0.9937/0.9390,         Elapsed/Remaining time: 13.30/0.85 [min]
# 48/50 Epoch, Train/Test Loss: 0.0114/0.4501,         Train/Test Accuracy: 0.9976/0.9478,         Elapsed/Remaining time: 13.57/0.57 [min]
# 49/50 Epoch, Train/Test Loss: 0.1641/0.7038,         Train/Test Accuracy: 0.9628/0.8937,         Elapsed/Remaining time: 13.84/0.28 [min]
# 50/50 Epoch, Train/Test Loss: 0.0471/0.4797,         Train/Test Accuracy: 0.9905/0.9304,         Elapsed/Remaining time: 14.11/0.00 [min]

# %%
# Save result
torch.save(model.state_dict(), os.path.join(out, 'final_model.pt'))

np.savez(os.path.join(out, 'log.npz'), **trainer.log)

# %%
# Plot and save log figures
log = np.load(os.path.join(out, 'log.npz'))
bd.plot_util.plot_training_logs(log, out)

# %% [markdown]
# ## 検証

# %%
val_model = net.CNV()
dummy_input = torch.Tensor(np.zeros((1, 3, 32, 32)).astype(np.float32))
val_model(dummy_input)
val_model.load_state_dict(torch.load(os.path.join(out, 'best_model.pt')))
val_model = val_model.eval()

evaluator = bd.Evaluator(val_model, 43, device=device)

# %%
# Evaluation against clean dataset
ret = evaluator.run(
    test_dl,
    out=os.path.join(out, 'clean_test'),
    cmap='Blues',
    fmt='d',
    annot=False,
    cbar=True
)
# Out:
# Accuracy: 0.9483768804433887

# %%
# Evaluation against poison dataset
ret = evaluator.run(
    test_p_dl,
    out=os.path.join(out, 'poison_test'),
    cmap='Blues',
    fmt='d',
    annot=False,
    cbar=True
)
# Out:
# Accuracy: 0.8871921182266009
